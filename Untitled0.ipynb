# %% [markdown]
# <a href="https://colab.research.google.com/github/TranKhanhDoan/Kh-nh-oan-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('text.txt',mode='w')as accounts:
  accounts.write('1 Nguyen van A 8.0\n')
  accounts.write('2 Le Thi B 6.8\n')

# %%
with open('text1.txt', mode ='w') as accounts:
  print('7:00 Nguyen Van A', file=accounts)
  print('7:01 Le Thi B', file=accounts)

# %%
with open ('text.txt', mode='r')as accounts:
  print(f'{'name':<20}{'score':>20}')
  for record in accounts:
    name,score= record.split()
    print(f'{name:<20}{score:>20}')
# Out:
#   File "<ipython-input-9-082b6cfd4fdf>", line 2
#     print(f'{'name':<20}{'score':>20}')
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
url='/content/AI.csv'
datafarme=pd.read_csv(url)
datafarme.head(10)

# %%
import pandas as pd
url= 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data[data['Medal']=='Gold'].head()

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data['NOC'].value_counts()

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.

# %%
from openpyxl import Workbook
wb=Workbook()
sheet= wb.active
sheet['A1']= 'Nguyen Van A'
sheet['B1']= '20104023'
sheet['A2']= 'Hung Minh Tran Dinh'
sheet['B2']= '20104022'
wb.save('test.xlsx')

# %%
import openpyxl
wb = openpyxl.load_workbook('test.xlsx')
sheet = wb.active
t1 = sheet['A1']
t2 = sheet['B1']
t3 = sheet.cell(row = 2, column = 1)
t4 = sheet.cell(row = 2, column = 2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A 20104023
# Hung Minh Tran Dinh 20104022

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x + 1
plt.plot(x,y,'o--')
plt.show()

# %%
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.show()

# %%
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.title('y = x and y = -x')
plt.xlabel('x')
plt.xlabel('y')
plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
N = 16
x = np,linspace(0,15,16)
y = x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
x = np.arange(25)
plt.plot(x,(x**3)+1)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x)
plt.grid(True)
plt.savefig('test.png')
plt.show()

# %%
x=arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2,color='r')
plt.subplot(2,2,2)
plt.plot(x,-x**3,color='g')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o')
plt.show()

# %%
plt.axis([0,100,0,10])
plt.scatter(20,5,s=1000,color='b',alpha=1)
plt.scatter(50,5,s=1000,color='b',alpha=.5)
plt.scatter(80,5,s=1000,color='b',alpha=.1)
plt.show()

# %%
x=np.arange(4)
y=np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0],color='b',width=0.25)
plt.bar(x+0.25,y[1],color='y',width=0.25)
plt.bar(x+0.5,y[2],color='r',width=0.25)
plt.show()

# %%
plt.axis([0,20, 0,20])
plt.arrow(12,0,0,6, head_length=4, head_width=2, color='g')
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors= np.random.rand(N)
size=20
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()

# %%
import numpy as np
import skfuzzy as fuzz

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 13.0 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=de98eb22cbca78be198079576a307592d9cb309fa3d54de6edc2dee4f95a0104
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tipping = ctrl.Consequent(np.arange(10,25,1),'tipping') 
food['poor']= fuzz.trimf(food.universe,[0,0,5])
food['average']= fuzz.trimf(food.universe,[0,5,10])
food['awesome']= fuzz.trimf(food.universe,[5,7,10])
service['poor']= fuzz.trimf(service.universe,[0,0,5])
service['average']= fuzz.trimf(service.universe,[0,5,10])
service['awesome']= fuzz.trimf(service.universe,[5,10,10])
tipping['less']= fuzz.trimf(tipping.universe,[10,10,18])
tipping['average']= fuzz.trimf(tipping.universe,[10,18,25])
tipping['awesome']= fuzz.trimf(tipping.universe,[18,22,25])
service.view()
food.view()
tipping.view()

# %%
rule1 = ctrl.Rule(food['poor']&service['poor'],tip['less'])
rule2 = ctrl.Rule(food['poor']&service['average'],tip['less'])
rule3 = ctrl.Rule(food['poor']&service['good'],tip['normal'])
rule4 = ctrl.Rule(food['average']&service['poor'],tip['less'])
rule5 = ctrl.Rule(food['average']&service['average'],tip['normal'])
rule6 = ctrl.Rule(food['average']&service['good'],tip['much'])
rule7 = ctrl.Rule(food['good']&service['poor'],tip['normal'])
rule8 = ctrl.Rule(food['good']&service['average'],tip['much'])
rule9 = ctrl.Rule(food['good']&service['good'],tip['much'])
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6, rule7,rule8,rule9])
tipping = ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food'] = 6.2
tipping.input['service'] = 3.5
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
time = ctrl.Antecedent(np.arange(10,123,7),'time')
rice = ctrl.Antecedent(np.arange(100,1000,5),'rice')
power = ctrl.Consequent(np.arange(0,1.5,0.3),'power') 
time['rat ngan']= fuzz.trimf(time.universe,[10,10,20])
time['ngan']= fuzz.trimf(time.universe,[10,20,30])
time['vua du']= fuzz.trimf(time.universe,[20,30,80])
time['dai']= fuzz.trimf(time.universe,[30,80,110])
time['rat dai']= fuzz.trimf(time.universe,[80,110,120])
rice['bi song']= fuzz.trimf(rice.universe,[100,100,300])
rice['bi nhao']= fuzz.trimf(rice.universe,[100,300,500])
rice['vua chin']= fuzz.trimf(rice.universe,[300,500,900])
rice['bi chay']= fuzz.trimf(rice.universe,[500,900,1000])
power['Yeu']= fuzz.trimf(power.universe,[0,0,0.2])
power['Binh thuong']= fuzz.trimf(power.universe,[0,0.2,0.6])
power['Kha manh']= fuzz.trimf(power.universe,[0.2,0.6,0.7])
power['Manh']= fuzz.trimf(power.universe,[0.7,1,1])
time.view()
rice.view()
power.view()
power['Binh thuong'].view()
rule1=ctrl.Rule(time['rat dai'] & rice['bi song'], power['Yeu'])
rule2=ctrl.Rule(time['rat dai'] & rice['bi nhao'],power['Yeu'])
rule3=ctrl.Rule(time['rat dai'] & rice['bi chay'],power['Manh'])
rule4=ctrl.Rule(time['rat dai'] & rice['bi song'],power['Yeu'])
rule5=ctrl.Rule(time['rat dai'] & rice['bi nhao'],power['Binh thuong'])
rule6=ctrl.Rule(time['vua du'] & rice['bi chay'],power['Manh'])
rule7=ctrl.Rule(time['vua du'] & rice['bi song'],power['Binh thuong'])
rule8=ctrl.Rule(time['dai'] & rice['bi nhao'],power['Binh thuong'])
rule9=ctrl.Rule(time['dai'] & rice['bi chay'],power['Manh'])
rule10=ctrl.Rule(time['rat dai'] & rice['vua chin'],power['Kha manh'])
rule11=ctrl.Rule(time['rat dai'] & rice['bi nhao'],power['Binh thuong'])
rule12=ctrl.Rule(time['rat dai'] & rice['bi song'],power['Binh thuong'])
rule13=ctrl.Rule(time['rat dai'] & rice['bi chay'],power['Manh'])

powerinput_ctrl=ctrl.ControlSystem([rule1,rule2,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13])
powerinput=ctrl.ControlSystemSimulation(powerinput_ctrl)
powerinput.input['time']= 60
powerinput.input['rice'] = 700
powerinput.compute()
print(powerinput.output['power'])
power.view(sim=powerinput)

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl

# %%
from matplotlib.font_manager import win32FontDirectory
from networkx.algorithms.bipartite.basic import color
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
wind = ctrl.Antecedent(np.arange(0.7,3.1,0.4),'windspeed')
temperature = ctrl.Antecedent(np.arange(20.4,41.2,5),'temperature')
rainfall = ctrl.Consequent(np.arange(0.2,9.1,0.87),'rainfall') 
wind['low']= fuzz.trimf(wind.universe,[0.7,0.7,1.5])
wind['medium']= fuzz.trimf(windspeed.universe,[0.7,1.5,3.1])
win32FontDirectory['high']= fuzz.trimf(windspeed.universe,[1.5,3.1,3.1])
temperature['low']= fuzz.trimf(temperature.universe,[20.4,20.4,35])
temperature['medium']= fuzz.trimf(temperature.universe,[20.4,35,41.2])
temperature['high']= fuzz.trimf(temperature.universe,[35,41.2,41.2])
rainfall['low']= fuzz.trimf(rainfall.universe,[0.2,0.2,4])
rainfall['medium']= fuzz.trimf(rainfall.universe,[0.2,4,9.1])
rainfall['high']= fuzz.trimf(rainfall.universe,[4,9.1,9.1])

windspeed.view()
temperature.view()
rainfall.view()
rainfall['medium'].view()
rule1=ctrl.Rule(windspeed['low'] & temperature['low'], rainfall['low'])
rule2=ctrl.Rule(windspeed['low'] & temperature['medium'],rainfall['medium'])
rule3=ctrl.Rule(windspeed['low'] & temperature['high'],rainfall['high'])
rule4=ctrl.Rule(windspeed['medium'] & temperature['low'],rainfall['low'])
rule5=ctrl.Rule(windspeed['medium'] & temperature['medium'],rainfall['high'])
rule6=ctrl.Rule(windspeed['medium'] & temperature['high'],rainfall['high'])
rule7=ctrl.Rule(windspeed['high'] & temperature['low'],rainfall['low'])
rule8=ctrl.Rule(windspeed['high'] & temperature['medium'],rainfall['medium'])
rule9=ctrl.Rule(windspeed['high'] & temperature['high'],rainfall['high'])

rain_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
rain=ctrl.ControlSystemSimulation(rain_ctrl)
rain.input['windspeed'] = 2.4
rain.input['temperature'] = 35
rain.compute()
print(rain.output['rainfall'])
rainfall.view(sim=rain)

# %%
from networkx.algorithms.bipartite.basic import color
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
Hight = ctrl.Antecedent(np.arange(0.7,3.1,0.4),'Hight')
Weight = ctrl.Antecedent(np.arange(20.4,41.2,5),'Weight')
BMI = ctrl.Consequent(np.arange(0.2,9.1,0.87),'BMI')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/Salary_Data.csv')
data.head()
data.shift()
X = data.drop(['Salary'], axis=True)
Y = data['Salary']
print(X)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-f45022319931> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
#       3 x_train.shape, x_test.shape, y_train.shape, y_test.shape
#       4 sns.pairplot(data)
#       5
#
# NameError: name 'x' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/Salary_Data.csv')
data.head()
data.shape
x=data.drop(['Salary'], axis=True)
y=data['Salary']
print(y)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
plt.plot(X_train,y_train,'r',label='Train data')
plt.xlabel('Salary')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test).round(1)
cal=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predict Salary'])
print('Coeffient',model.coef_)
print('Intercept',model.intercept_)
print('Accuracy',model.score(x_test,y_test))
# Out:
# Coeffient [9423.81532303]
# Intercept 25321.583011776813
# Accuracy 0.9024461774180497

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test).round(1)
cal=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predict Salary'])
print('Coeffient',model.coef_)
print('Intercept',model.intercept_)
print('Accuracy',model.score(x_test,y_test))
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_train,model.predict(x_train),color='blue')
plt.title('Salary vs Exrience')
plt.xlabel('Years of Exprience')
plt.ylabel('Salary')
plt.show()
# Out:
# Coeffient [9423.81532303]
# Intercept 25321.583011776813
# Accuracy 0.9024461774180497

# %%
import numpy as np
from sklearn.linear_model import Perceptron
x=[[0,0],[1,0],[0,1],[1,1]]
y=[0,1,1,1]
model= Perceptron()
model.fit(x,y) 
print('Do chinh xac',model.score(x,y))
x_test=[[0.6,0],[0.7,-0.3],[1,-0.4],[0.2,0.7]]
y_test=model.predict(x_test)
print(y_test)
# Out:
# Do chinh xac 1.0
# [1 0 1 1]

# %%
import numpy as np
from sklearn.linear_model import Perceptron
x=[[-0.5,-0.5],[-0.5,0.5],[0.3,-0.5],[-0.1,1]]
y=[1,1,0,0]
model= Perceptron()
model.fit(x,y) 
print('Do chinh xac',model.score(x,y))
x_test=[[-0.6,0],[0.5,-0.5],[1,-0.4],[0.2,0.7]]
y_test=model.predict(x_test)
print(y_test)
# Out:
# Do chinh xac 1.0
# [1 0 0 0]

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_csv("crabs.csv")
x = data.drop(data.columns[[0,1,2]], axis=1)
y = data["sex"].replace(["M","F"],["1","0"])
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)
model = Perceptron()
model.fit(x_train, y_train)
print(" do chinh xac: ", model.score(x_train,y_train))
x_test = [[7.1,3.7,17.1,13,5],[10.5,9.4,21.7,35.4,9.3]]
y_test = model.predict(x_test)
print(y_test)
# Out:
#  do chinh xac:  0.5142857142857142
# ['1' '1']
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"

# %%
from keras.datasets import mnist
(train_images,train_labels),(test_images,test_labels) = mnist.load_data()
train_images.shape
train_labels.shape
test_images.shape
test_labels.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as plt 
plt.imshow(train_images[18])
plt.show()
print(train_labels[18])

# %%
from tensorflow.python import summary
from keras.layers.serialization import activation
from keras import models
from keras import layers
model= models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
train_images=train_images.reshape((60000,784))
train_images=train_images.astype('float32')/255
test_images=test_images.reshape(10000,784)
test_images=test_images.astype('float32')/255
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 512)               401920
#
#  dense_25 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical
from tensorflow.python import summary
from keras.layers.serialization import activation
from keras import models
from keras import layers
model= models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
train_images=train_images.reshape((60000,784))
train_images=train_images.astype('float32')/255
test_images=test_images.reshape(10000,784)
test_images=test_images.astype('float32')/255
train_labels=to_categorical(train_labels)
test_labels= to_categorical(test_labels)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 512)               401920
#
#  dense_27 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import models
from keras import layers
from keras import Sequential
model.compile(optimizer='rmsprop',less='categori')

# %%
from keras.datasets import fashion_mnist
(x_train,y_train),(x_test,y_test)= fashion_mnist.load_data()

# %%
x_train.shape

# %%
y_train.shape

# %%
x_test.shape

# %%
y_test.shape

# %%
import matplotlib.pyplot as plt
class_name=['T-shirt','Trousers','Dress','Coat','Sandal','Shirt','Sneaker','Bag','A','sneaker','hoodie']
plt.imshow(x_train[99])
plt.show()
print(class_name[y_train[10]])
# Out:
# T-shirt

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test)= fashion_mnist.load_data()
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images.shape
train_labels.shape
test_images.shape
test_labels.shape
from keras.layers.serialization import activation
from keras import models
from keras import layers
from keras.utils import to_categorical
model = models.Sequential()
model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax'))
model.summary()
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255
test_images = test_images.reshape(10000,28*28)
test_images = test_images.astype('float32')/255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy' , metrics= 'accuracy' )
model.fit(train_images,train_labels,epochs=10,batch_size=128)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_28 (Dense)            (None, 512)               401920
#
#  dense_29 (Dense)            (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2557 - accuracy: 0.9259
# Epoch 2/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1022 - accuracy: 0.9703
# Epoch 3/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0676 - accuracy: 0.9798
# Epoch 4/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0496 - accuracy: 0.9848
# Epoch 5/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0372 - accuracy: 0.9886
# Epoch 6/10
# ...

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test)= fashion_mnist.load_data()
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
x_train.shape
y_train.shape
x_test.shape
y_test.shape
from keras.layers.serialization import activation
from keras import models
from keras import layers
from keras.utils import to_categorical
model = models.Sequential()
model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax'))
model.summary()
x_train = train_images.reshape((60000,28*28))
y_train = train_images.astype('float32')/255
x_test = test_images.reshape(10000,28*28)
y_test = test_images.astype('float32')/255
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy' , metrics= 'accuracy' )
model.fit(x_train,y_train,epochs=5,batch_size=128)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 512)               401920
#
#  dense_3 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 5.0563 - accuracy: 0.9008
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.6405 - accuracy: 0.9530
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.4344 - accuracy: 0.9658
# Epoch 4/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3804 - accuracy: 0.9728
# Epoch 5/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3173 - accuracy: 0.9777

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from keras.utils import load_img, img_to_array
url='/content/download.jfif'
img= load_img(url, target_size=(28,28))
plt.imshow(img)
img = img_to_array(img)
img= img.reshape(1,784,3)
img= img.astype('float32')
img= img/255
np.argmax(model.predict(img), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0c8348191d4a> in <module>
#       2 from keras.utils import load_img, img_to_array
#       3 url='/content/download.jfif'
# ----> 4 img= load_img(url, target_size=(28,28))
#       5 plt.imshow(img)
#       6 img = img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/download.jfif'

# %%
from keras.utils import img_to_array
from keras.utils import load_img
import numpy as np
import matplotlib.pyplot as plt
#url=url.reshape(28*28,)
img=load_img('/45fb739c15961b2ed42b544fd8f98bc5.jpg',target_size=(28,28))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,28,28,3)
img=img.astype('float32')
img=img/255
np.argmax(model.predict(img),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-444f3147c9de> in <module>
#      10 img=img.astype('float32')
#      11 img=img/255
# ---> 12 np.argmax(model.predict(img),axis=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ...
